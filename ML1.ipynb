# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp310-cp310-win_amd64.whl (11.6 MB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pujar\appdata\roaming\python\python310\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1
#   Downloading pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\pujar\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.2.1)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Requirement already satisfied: six>=1.5 in c:\users\pujar\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Installing collected packages: tzdata, pytz, pandas
# Successfully installed pandas-2.2.3 pytz-2025.1 tzdata-2025.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.0 is available.
# You should consider upgrading via the 'c:\Users\pujar\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.4-cp310-cp310-win_amd64.whl (9.8 MB)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\pujar\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (1.14.1)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\pujar\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (2.2.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\pujar\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (2.2.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\pujar\appdata\roaming\python\python310\site-packages (from statsmodels) (24.2)
# Collecting patsy>=0.5.6
#   Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pujar\appdata\local\programs\python\python310\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pujar\appdata\roaming\python\python310\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pujar\appdata\local\programs\python\python310\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\pujar\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-1.0.1 statsmodels-0.14.4
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.0 is available.
# You should consider upgrading via the 'c:\Users\pujar\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.0-cp310-cp310-win_amd64.whl (8.0 MB)
# Requirement already satisfied: numpy>=1.23 in c:\users\pujar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.2.1)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.1-cp310-cp310-win_amd64.whl (218 kB)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.8-cp310-cp310-win_amd64.whl (71 kB)
# Collecting pillow>=8
#   Downloading pillow-11.1.0-cp310-cp310-win_amd64.whl (2.6 MB)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\pujar\appdata\roaming\python\python310\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pujar\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.55.8-cp310-cp310-win_amd64.whl (2.2 MB)
# Requirement already satisfied: six>=1.5 in c:\users\pujar\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.55.8 kiwisolver-1.4.8 matplotlib-3.10.0 pillow-11.1.0 pyparsing-3.2.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\pujar\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 21.2.3; however, version 25.0 is available.
# You should consider upgrading via the 'c:\Users\pujar\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score
import tensorflow as tf
from statsmodels.tsa.arima.model import ARIMA

# Load dataset
df = pd.read_csv("data_season.csv")

# Preprocessing
le = LabelEncoder()
for col in ["Location", "Soil type", "Irrigation", "Crops", "Season"]:
    df[col] = le.fit_transform(df[col].astype(str))

def crop_yield_prediction():
    features = ["Rainfall", "Temperature", "Soil type", "Irrigation", "Humidity", "Area"]
    target = "yeilds"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestRegressor()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Crop Yield Prediction - MAE:", mean_absolute_error(y_test, predictions))

def crop_price_prediction():
    features = ["Year", "Location", "Crops", "yeilds", "Season"]
    target = "price"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = LinearRegression()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Crop Price Prediction - RMSE:", np.sqrt(mean_squared_error(y_test, predictions)))

def optimal_crop_selection():
    features = ["Rainfall", "Temperature", "Soil type", "Humidity"]
    target = "Crops"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Optimal Crop Selection - Accuracy:", accuracy_score(y_test, predictions))

def irrigation_recommendation():
    features = ["Crops", "Soil type", "Rainfall", "Temperature"]
    target = "Irrigation"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Irrigation Recommendation - Accuracy:", accuracy_score(y_test, predictions))

def seasonal_impact_analysis():
    grouped = df.groupby("Season")["yeilds", "price"].mean()
    print("Seasonal Impact Analysis:")
    print(grouped)

def soil_type_impact_analysis():
    grouped = df.groupby("Soil type")["yeilds"].mean()
    print("Soil Type Impact Analysis:")
    print(grouped)

def climate_impact_analysis():
    features = ["Rainfall", "Temperature", "Crops"]
    target = "yeilds"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestRegressor()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Climate Impact Analysis - MAE:", mean_absolute_error(y_test, predictions))

def crop_rotation_planning():
    features = ["Soil type", "Location", "Season", "Crops"]
    target = "Crops"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Crop Rotation Planning - Accuracy:", accuracy_score(y_test, predictions))

def predictive_maintenance_irrigation():
    features = ["Irrigation", "Crops", "Soil type", "Temperature"]
    target = "Irrigation"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Predictive Maintenance - Accuracy:", accuracy_score(y_test, predictions))

def main():
    crop_yield_prediction()
    crop_price_prediction()
    optimal_crop_selection()
    irrigation_recommendation()
    seasonal_impact_analysis()
    soil_type_impact_analysis()
    climate_impact_analysis()
    crop_rotation_planning()
    predictive_maintenance_irrigation()

if __name__ == "__main__":
    main()
# Out:
# Crop Yield Prediction - MAE: 30717.80707120253
# Crop Price Prediction - RMSE: 93168.8679807777
# Optimal Crop Selection - Accuracy: 0.7009493670886076
# Irrigation Recommendation - Accuracy: 0.9018987341772152
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 111
#     108     predictive_maintenance_irrigation()
#     110 if __name__ == "__main__":
# --> 111     main()
#
# Cell In[6], line 104, in main()
#     102 optimal_crop_selection()
#     103 irrigation_recommendation()
# --> 104 seasonal_impact_analysis()
#     105 soil_type_impact_analysis()
#     106 climate_impact_analysis()
#
# Cell In[6], line 60, in seasonal_impact_analysis()
#      59 def seasonal_impact_analysis():
# ---> 60     grouped = df.groupby("Season")["yeilds", "price"].mean()
#      61     print("Seasonal Impact Analysis:")
#      62     print(grouped)
#
# File c:\Users\pujar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\generic.py:1947, in DataFrameGroupBy.__getitem__(self, key)
#    1943 # per GH 23566
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
# -> 1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
#    1951 return super().__getitem__(key)
#
# ValueError: Cannot subset columns with a tuple with more than one element. Use a list instead.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score
import tensorflow as tf
from statsmodels.tsa.arima.model import ARIMA

# Load dataset
df = pd.read_csv("data_season.csv")

# Standardize column names
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# Preprocessing
le = LabelEncoder()
for col in ["location", "soil_type", "irrigation", "crops", "season"]:
    df[col] = le.fit_transform(df[col].astype(str))

def crop_yield_prediction():
    features = ["rainfall", "temperature", "soil_type", "irrigation", "humidity", "area"]
    target = "yields"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestRegressor()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Crop Yield Prediction - MAE:", mean_absolute_error(y_test, predictions))

def crop_price_prediction():
    features = ["year", "location", "crops", "yields", "season"]
    target = "price"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = LinearRegression()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Crop Price Prediction - RMSE:", np.sqrt(mean_squared_error(y_test, predictions)))

def optimal_crop_selection():
    features = ["rainfall", "temperature", "soil_type", "humidity"]
    target = "crops"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Optimal Crop Selection - Accuracy:", accuracy_score(y_test, predictions))

def irrigation_recommendation():
    features = ["crops", "soil_type", "rainfall", "temperature"]
    target = "irrigation"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Irrigation Recommendation - Accuracy:", accuracy_score(y_test, predictions))

def seasonal_impact_analysis():
    grouped = df.groupby("season")[["yields", "price"]].mean()
    print("Seasonal Impact Analysis:")
    print(grouped)

def soil_type_impact_analysis():
    grouped = df.groupby("soil_type")["yields"].mean()
    print("Soil Type Impact Analysis:")
    print(grouped)

def climate_impact_analysis():
    features = ["rainfall", "temperature", "crops"]
    target = "yields"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestRegressor()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Climate Impact Analysis - MAE:", mean_absolute_error(y_test, predictions))

def crop_rotation_planning():
    features = ["soil_type", "location", "season", "crops"]
    target = "crops"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Crop Rotation Planning - Accuracy:", accuracy_score(y_test, predictions))

def predictive_maintenance_irrigation():
    features = ["irrigation", "crops", "soil_type", "temperature"]
    target = "irrigation"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Predictive Maintenance - Accuracy:", accuracy_score(y_test, predictions))

def main():
    crop_yield_prediction()
    crop_price_prediction()
    optimal_crop_selection()
    irrigation_recommendation()
    seasonal_impact_analysis()
    soil_type_impact_analysis()
    climate_impact_analysis()
    crop_rotation_planning()
    predictive_maintenance_irrigation()

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pujar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'yields'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 114
#     111     predictive_maintenance_irrigation()
#     113 if __name__ == "__main__":
# --> 114     main()
#
# Cell In[9], line 103, in main()
#     102 def main():
# --> 103     crop_yield_prediction()
#     104     crop_price_prediction()
#     105     optimal_crop_selection()
#
# Cell In[9], line 25, in crop_yield_prediction()
#      23 features = ["rainfall", "temperature", "soil_type", "irrigation", "humidity", "area"]
#      24 target = "yields"
# ---> 25 X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
#      27 model = RandomForestRegressor()
#      28 model.fit(X_train, y_train)
#
# File c:\Users\pujar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\pujar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'yields'

# %%
df.columns
# Out:
# Index(['year', 'location', 'area', 'rainfall', 'temperature', 'soil_type',
#        'irrigation', 'yeilds', 'humidity', 'crops', 'price', 'season'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# year           0
# location       0
# area           0
# rainfall       0
# temperature    0
# soil_type      0
# irrigation     0
# yeilds         0
# humidity       0
# crops          0
# price          0
# season         0
# dtype: int64

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score
import tensorflow as tf
from statsmodels.tsa.arima.model import ARIMA

# Load dataset
df = pd.read_csv("data_season.csv")

# Standardize column names
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# Preprocessing
le = LabelEncoder()
for col in ["location", "soil_type", "irrigation", "crops", "season"]:
    if col in df.columns:
        df[col] = le.fit_transform(df[col].astype(str))

def crop_yield_prediction():
    features = ["rainfall", "temperature", "soil_type", "irrigation", "humidity", "area"]
    target = "yeilds"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestRegressor()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Crop Yield Prediction - MAE:", mean_absolute_error(y_test, predictions))

def crop_price_prediction():
    features = ["year", "location", "crops", "yeilds", "season"]
    target = "price"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = LinearRegression()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Crop Price Prediction - RMSE:", np.sqrt(mean_squared_error(y_test, predictions)))

def optimal_crop_selection():
    features = ["rainfall", "temperature", "soil_type", "humidity"]
    target = "crops"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Optimal Crop Selection - Accuracy:", accuracy_score(y_test, predictions))

def irrigation_recommendation():
    features = ["crops", "soil_type", "rainfall", "temperature"]
    target = "irrigation"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Irrigation Recommendation - Accuracy:", accuracy_score(y_test, predictions))

def seasonal_impact_analysis():
    grouped = df.groupby("season")[["yeilds", "price"]].mean()
    print("Seasonal Impact Analysis:")
    print(grouped)

def soil_type_impact_analysis():
    grouped = df.groupby("soil_type")["yeilds"].mean()
    print("Soil Type Impact Analysis:")
    print(grouped)

def climate_impact_analysis():
    features = ["rainfall", "temperature", "crops"]
    target = "yeilds"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestRegressor()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Climate Impact Analysis - MAE:", mean_absolute_error(y_test, predictions))

def crop_rotation_planning():
    features = ["soil_type", "location", "season", "crops"]
    target = "crops"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Crop Rotation Planning - Accuracy:", accuracy_score(y_test, predictions))

def predictive_maintenance_irrigation():
    features = ["irrigation", "crops", "soil_type", "temperature"]
    target = "irrigation"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Predictive Maintenance - Accuracy:", accuracy_score(y_test, predictions))

def main():
    crop_yield_prediction()
    crop_price_prediction()
    optimal_crop_selection()
    irrigation_recommendation()
    seasonal_impact_analysis()
    soil_type_impact_analysis()
    climate_impact_analysis()
    crop_rotation_planning()
    predictive_maintenance_irrigation()

if __name__ == "__main__":
    main()
# Out:
# Crop Yield Prediction - MAE: 31211.209908544304
# Crop Price Prediction - RMSE: 93168.8679807777
# Optimal Crop Selection - Accuracy: 0.7025316455696202
# Irrigation Recommendation - Accuracy: 0.9050632911392406
# Seasonal Impact Analysis:
#               yeilds         price
# season
# 0       20184.694926  86171.280066
# 1       24916.966969  86684.499426
# 2       21995.528826  85456.532756
# Soil Type Impact Analysis:
# soil_type
# 0     24181.168845
# 1     19359.364697
# 2     21629.660232
# 3     14881.800000
# 4     40383.923810
# 5     10979.882653
# 6      8631.247059
# 7     41245.469100
# 8     13524.750000
# 9      9655.500000
# 10    12621.233333
# 11    18641.722100
# 12     2274.275862
# 13    20013.166940
# 14    17715.523810
# 15    16819.650000
# 16    37665.494118
# 17    24452.671875
# 18    14609.760000
# 19    76959.833333
# 20    18161.275132
# 21    36890.520000
# 22    32161.558075
# 23    15705.281991
# 24    16295.000000
# 25    60599.564103
# 26    20851.551724
# 27    14632.189655
# Name: yeilds, dtype: float64
# Climate Impact Analysis - MAE: 30812.1248139037
# Crop Rotation Planning - Accuracy: 1.0
# Predictive Maintenance - Accuracy: 1.0

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score
import tensorflow as tf
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("data_season.csv")

# Standardize column names
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# Preprocessing
le = LabelEncoder()
for col in ["location", "soil_type", "irrigation", "crops", "season"]:
    if col in df.columns:
        df[col] = le.fit_transform(df[col].astype(str))

def crop_yield_prediction():
    features = ["rainfall", "temperature", "soil_type", "irrigation", "humidity", "area"]
    target = "yeilds"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestRegressor()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Crop Yield Prediction - MAE:", mean_absolute_error(y_test, predictions))

def crop_price_prediction():
    features = ["year", "location", "crops", "yeilds", "season"]
    target = "price"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = LinearRegression()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Crop Price Prediction - RMSE:", np.sqrt(mean_squared_error(y_test, predictions)))

def crop_price_forecasting():
    df_sorted = df.sort_values(by="year")
    price_series = df_sorted.groupby("year")["price"].mean()
    
    train_size = int(len(price_series) * 0.8)
    train, test = price_series[:train_size], price_series[train_size:]
    
    model = ARIMA(train, order=(5,1,0))  # ARIMA(p,d,q) parameters
    model_fit = model.fit()
    forecast = model_fit.forecast(steps=len(test))
    
    plt.figure(figsize=(10,5))
    plt.plot(price_series.index, price_series, label="Actual Prices")
    plt.plot(test.index, forecast, label="Forecasted Prices", linestyle="dashed")
    plt.xlabel("Year")
    plt.ylabel("Average Crop Price")
    plt.title("Crop Price Forecasting using ARIMA")
    plt.legend()
    plt.show()
    
    print("ARIMA Forecasted Prices:", forecast)

def optimal_crop_selection():
    features = ["rainfall", "temperature", "soil_type", "humidity"]
    target = "crops"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Optimal Crop Selection - Accuracy:", accuracy_score(y_test, predictions))

def irrigation_recommendation():
    features = ["crops", "soil_type", "rainfall", "temperature"]
    target = "irrigation"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Irrigation Recommendation - Accuracy:", accuracy_score(y_test, predictions))

def seasonal_impact_analysis():
    grouped = df.groupby("season")[["yeilds", "price"]].mean()
    print("Seasonal Impact Analysis:")
    print(grouped)

def soil_type_impact_analysis():
    grouped = df.groupby("soil_type")["yeilds"].mean()
    print("Soil Type Impact Analysis:")
    print(grouped)

def climate_impact_analysis():
    features = ["rainfall", "temperature", "crops"]
    target = "yeilds"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestRegressor()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Climate Impact Analysis - MAE:", mean_absolute_error(y_test, predictions))

def crop_rotation_planning():
    features = ["soil_type", "location", "season", "crops"]
    target = "crops"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Crop Rotation Planning - Accuracy:", accuracy_score(y_test, predictions))

def predictive_maintenance_irrigation():
    features = ["irrigation", "crops", "soil_type", "temperature"]
    target = "irrigation"
    X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
    
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print("Predictive Maintenance - Accuracy:", accuracy_score(y_test, predictions))

def main():
    crop_yield_prediction()
    crop_price_prediction()
    crop_price_forecasting()
    optimal_crop_selection()
    irrigation_recommendation()
    seasonal_impact_analysis()
    soil_type_impact_analysis()
    climate_impact_analysis()
    crop_rotation_planning()
    predictive_maintenance_irrigation()

if __name__ == "__main__":
    main()
# Out:
# Crop Yield Prediction - MAE: 31266.16955664557
# Crop Price Prediction - RMSE: 93168.8679807777
# c:\Users\pujar\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\pujar\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\pujar\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# c:\Users\pujar\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\pujar\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\pujar\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# ARIMA Forecasted Prices: 12    82269.136034
# 13    82093.952455
# 14    85579.528067
# 15    82164.290778
# Name: predicted_mean, dtype: float64
# Optimal Crop Selection - Accuracy: 0.6882911392405063
# Irrigation Recommendation - Accuracy: 0.9066455696202531
# Seasonal Impact Analysis:
#               yeilds         price
# season
# 0       20184.694926  86171.280066
# 1       24916.966969  86684.499426
# 2       21995.528826  85456.532756
# Soil Type Impact Analysis:
# soil_type
# 0     24181.168845
# 1     19359.364697
# 2     21629.660232
# 3     14881.800000
# 4     40383.923810
# 5     10979.882653
# 6      8631.247059
# 7     41245.469100
# 8     13524.750000
# 9      9655.500000
# 10    12621.233333
# 11    18641.722100
# 12     2274.275862
# 13    20013.166940
# 14    17715.523810
# 15    16819.650000
# 16    37665.494118
# 17    24452.671875
# 18    14609.760000
# 19    76959.833333
# 20    18161.275132
# 21    36890.520000
# 22    32161.558075
# 23    15705.281991
# 24    16295.000000
# 25    60599.564103
# 26    20851.551724
# 27    14632.189655
# Name: yeilds, dtype: float64
# Climate Impact Analysis - MAE: 30727.523796038036
# Crop Rotation Planning - Accuracy: 1.0
# Predictive Maintenance - Accuracy: 1.0

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler

def crop_price_forecasting_lstm():
    df_sorted = df.sort_values(by="year")
    price_series = df_sorted.groupby("year")["price"].mean().values.reshape(-1, 1)
    
    # Normalize the data (LSTM performs better with scaled data)
    scaler = MinMaxScaler(feature_range=(0, 1))
    price_scaled = scaler.fit_transform(price_series)
    
    # Prepare data for LSTM
    time_steps = 3  # Number of previous years to use for predicting the next year
    X, y = [], []
    for i in range(len(price_scaled) - time_steps):
        X.append(price_scaled[i:i + time_steps])
        y.append(price_scaled[i + time_steps])

    X, y = np.array(X), np.array(y)

    # Split into training and testing sets
    train_size = int(len(X) * 0.8)
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]

    # Define LSTM model
    model = Sequential([
        LSTM(50, activation='relu', return_sequences=True, input_shape=(time_steps, 1)),
        LSTM(50, activation='relu'),
        Dense(1)
    ])

    # Compile the model
    model.compile(optimizer="adam", loss="mean_squared_error")

    # Train the model
    model.fit(X_train, y_train, epochs=100, batch_size=8, verbose=1)

    # Make predictions
    predictions = model.predict(X_test)
    
    # Convert predictions back to original scale
    predictions = scaler.inverse_transform(predictions)
    y_test = scaler.inverse_transform(y_test)

    # Plot actual vs predicted prices
    plt.figure(figsize=(10, 5))
    plt.plot(range(len(y_test)), y_test, label="Actual Prices")
    plt.plot(range(len(predictions)), predictions, label="Predicted Prices", linestyle="dashed")
    plt.xlabel("Time")
    plt.ylabel("Crop Price")
    plt.title("LSTM Crop Price Forecasting")
    plt.legend()
    plt.show()

# Call the function to test it
crop_price_forecasting_lstm()
# Out:
# Epoch 1/100
# c:\Users\pujar\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.3488
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3599
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3483
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3210
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3002
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3197
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2959
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2777
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2650
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2632
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2431
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2389
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2117
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2043
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1871
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1824
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1523
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1385
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1152
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1016
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0915
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0866
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0784
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0694
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0790
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0861
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0902
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0886
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0982
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0952
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0761
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0869
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0745
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0798
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0772
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0769
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0733
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0711
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0733
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0664
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0740
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0692
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0716
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0659
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0641
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0718
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0697
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0719
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0705
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0717
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0627
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0701
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0690
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0600
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0645
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0658
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0635
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0612
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0689
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0594
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0601
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0677
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0674
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0654
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0612
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0558
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0609
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0608
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0518
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0636
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0540
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0532
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0612
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0547
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0549
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0588
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0514
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0573
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0512
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0539
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0516
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0551
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0454
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0520
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0466
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0459
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0503
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0505
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0516
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0468
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0505
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0442
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0484
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0494
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0487
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0417
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0462
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0409
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0457
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0411
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.preprocessing import MinMaxScaler

def crop_price_forecasting_lstm_improved():
    df_sorted = df.sort_values(by="year")
    price_series = df_sorted.groupby("year")["price"].mean().values.reshape(-1, 1)
    
    # Normalize the data
    scaler = MinMaxScaler(feature_range=(0, 1))
    price_scaled = scaler.fit_transform(price_series)
    
    # Prepare LSTM input
    time_steps = 5  # Using last 5 years to predict next year
    X, y = [], []
    for i in range(len(price_scaled) - time_steps):
        X.append(price_scaled[i:i + time_steps])
        y.append(price_scaled[i + time_steps])

    X, y = np.array(X), np.array(y)

    # Split into training and testing sets
    train_size = int(len(X) * 0.8)
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]

    # Define enhanced LSTM model
    model = Sequential([
        Bidirectional(LSTM(100, return_sequences=True, activation='relu'), input_shape=(time_steps, 1)),
        Dropout(0.2),  # Drop 20% of neurons to prevent overfitting
        LSTM(100, return_sequences=True, activation='relu'),
        Dropout(0.2),
        LSTM(50, activation='relu'),
        Dropout(0.2),
        Dense(1)  # Output layer
    ])

    # Compile the model
    model.compile(optimizer="adam", loss="mean_squared_error")

    # Reduce learning rate if no improvement in loss
    lr_reduction = ReduceLROnPlateau(monitor="loss", patience=5, factor=0.5, min_lr=0.0001)

    # Train the model
    model.fit(X_train, y_train, epochs=200, batch_size=8, verbose=1, callbacks=[lr_reduction])

    # Make predictions
    predictions = model.predict(X_test)
    
    # Convert predictions back to original scale
    predictions = scaler.inverse_transform(predictions)
    y_test = scaler.inverse_transform(y_test)

    # Plot actual vs predicted prices
    plt.figure(figsize=(10, 5))
    plt.plot(range(len(y_test)), y_test, label="Actual Prices")
    plt.plot(range(len(predictions)), predictions, label="Predicted Prices", linestyle="dashed")
    plt.xlabel("Time")
    plt.ylabel("Crop Price")
    plt.title("Improved LSTM Crop Price Forecasting")
    plt.legend()
    plt.show()

# Call the function to test the improved model
crop_price_forecasting_lstm_improved()
# Out:
# Epoch 1/200
# c:\Users\pujar\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.3867 - learning_rate: 0.0010
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.3734 - learning_rate: 0.0010
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.3587 - learning_rate: 0.0010
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.3477 - learning_rate: 0.0010
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.3268 - learning_rate: 0.0010
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.3134 - learning_rate: 0.0010
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2999 - learning_rate: 0.0010
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2844 - learning_rate: 0.0010
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.2667 - learning_rate: 0.0010
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.2296 - learning_rate: 0.0010
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2084 - learning_rate: 0.0010
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2002 - learning_rate: 0.0010
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1711 - learning_rate: 0.0010
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1270 - learning_rate: 0.0010
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1210 - learning_rate: 0.0010
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1063 - learning_rate: 0.0010
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1003 - learning_rate: 0.0010
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1207 - learning_rate: 0.0010
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1693 - learning_rate: 0.0010
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1781 - learning_rate: 0.0010
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1449 - learning_rate: 0.0010
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1231 - learning_rate: 0.0010
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0951 - learning_rate: 5.0000e-04
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1077 - learning_rate: 5.0000e-04
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1184 - learning_rate: 5.0000e-04
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1010 - learning_rate: 5.0000e-04
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0803 - learning_rate: 5.0000e-04
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1099 - learning_rate: 5.0000e-04
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0810 - learning_rate: 5.0000e-04
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0979 - learning_rate: 5.0000e-04
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0797 - learning_rate: 5.0000e-04
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0895 - learning_rate: 5.0000e-04
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1240 - learning_rate: 5.0000e-04
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1019 - learning_rate: 5.0000e-04
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0964 - learning_rate: 5.0000e-04
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1069 - learning_rate: 5.0000e-04
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1075 - learning_rate: 2.5000e-04
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0750 - learning_rate: 2.5000e-04
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.1027 - learning_rate: 2.5000e-04
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0710 - learning_rate: 2.5000e-04
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1032 - learning_rate: 2.5000e-04
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1231 - learning_rate: 2.5000e-04
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1069 - learning_rate: 2.5000e-04
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0823 - learning_rate: 2.5000e-04
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0971 - learning_rate: 2.5000e-04
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1039 - learning_rate: 1.2500e-04
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1195 - learning_rate: 1.2500e-04
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0836 - learning_rate: 1.2500e-04
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1291 - learning_rate: 1.2500e-04
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0900 - learning_rate: 1.2500e-04
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1115 - learning_rate: 1.0000e-04
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1054 - learning_rate: 1.0000e-04
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1115 - learning_rate: 1.0000e-04
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1023 - learning_rate: 1.0000e-04
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1043 - learning_rate: 1.0000e-04
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0983 - learning_rate: 1.0000e-04
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0766 - learning_rate: 1.0000e-04
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1297 - learning_rate: 1.0000e-04
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1169 - learning_rate: 1.0000e-04
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1022 - learning_rate: 1.0000e-04
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1076 - learning_rate: 1.0000e-04
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1142 - learning_rate: 1.0000e-04
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0939 - learning_rate: 1.0000e-04
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1238 - learning_rate: 1.0000e-04
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0963 - learning_rate: 1.0000e-04
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1077 - learning_rate: 1.0000e-04
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0827 - learning_rate: 1.0000e-04
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1082 - learning_rate: 1.0000e-04
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1171 - learning_rate: 1.0000e-04
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0876 - learning_rate: 1.0000e-04
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1148 - learning_rate: 1.0000e-04
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1100 - learning_rate: 1.0000e-04
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1168 - learning_rate: 1.0000e-04
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0893 - learning_rate: 1.0000e-04
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1013 - learning_rate: 1.0000e-04
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0998 - learning_rate: 1.0000e-04
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1148 - learning_rate: 1.0000e-04
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1137 - learning_rate: 1.0000e-04
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1098 - learning_rate: 1.0000e-04
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1335 - learning_rate: 1.0000e-04
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0930 - learning_rate: 1.0000e-04
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1122 - learning_rate: 1.0000e-04
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0822 - learning_rate: 1.0000e-04
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1059 - learning_rate: 1.0000e-04
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0915 - learning_rate: 1.0000e-04
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1230 - learning_rate: 1.0000e-04
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1091 - learning_rate: 1.0000e-04
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0760 - learning_rate: 1.0000e-04
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0999 - learning_rate: 1.0000e-04
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1058 - learning_rate: 1.0000e-04
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0923 - learning_rate: 1.0000e-04
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0925 - learning_rate: 1.0000e-04
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1159 - learning_rate: 1.0000e-04
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0924 - learning_rate: 1.0000e-04
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0847 - learning_rate: 1.0000e-04
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0981 - learning_rate: 1.0000e-04
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1030 - learning_rate: 1.0000e-04
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1218 - learning_rate: 1.0000e-04
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0882 - learning_rate: 1.0000e-04
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0789 - learning_rate: 1.0000e-04
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1074 - learning_rate: 1.0000e-04
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1063 - learning_rate: 1.0000e-04
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0932 - learning_rate: 1.0000e-04
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0897 - learning_rate: 1.0000e-04
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1162 - learning_rate: 1.0000e-04
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1468 - learning_rate: 1.0000e-04
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1125 - learning_rate: 1.0000e-04
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0934 - learning_rate: 1.0000e-04
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0978 - learning_rate: 1.0000e-04
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0833 - learning_rate: 1.0000e-04
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0989 - learning_rate: 1.0000e-04
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1115 - learning_rate: 1.0000e-04
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1103 - learning_rate: 1.0000e-04
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0990 - learning_rate: 1.0000e-04
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1064 - learning_rate: 1.0000e-04
# Epoch 116/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0991 - learning_rate: 1.0000e-04
# Epoch 117/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1016 - learning_rate: 1.0000e-04
# Epoch 118/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1114 - learning_rate: 1.0000e-04
# Epoch 119/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1278 - learning_rate: 1.0000e-04
# Epoch 120/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1075 - learning_rate: 1.0000e-04
# Epoch 121/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1142 - learning_rate: 1.0000e-04
# Epoch 122/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1080 - learning_rate: 1.0000e-04
# Epoch 123/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0918 - learning_rate: 1.0000e-04
# Epoch 124/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0804 - learning_rate: 1.0000e-04
# Epoch 125/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0960 - learning_rate: 1.0000e-04
# Epoch 126/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0957 - learning_rate: 1.0000e-04
# Epoch 127/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0994 - learning_rate: 1.0000e-04
# Epoch 128/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0973 - learning_rate: 1.0000e-04
# Epoch 129/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1023 - learning_rate: 1.0000e-04
# Epoch 130/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1015 - learning_rate: 1.0000e-04
# Epoch 131/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0912 - learning_rate: 1.0000e-04
# Epoch 132/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0963 - learning_rate: 1.0000e-04
# Epoch 133/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0980 - learning_rate: 1.0000e-04
# Epoch 134/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1093 - learning_rate: 1.0000e-04
# Epoch 135/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0753 - learning_rate: 1.0000e-04
# Epoch 136/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1095 - learning_rate: 1.0000e-04
# Epoch 137/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1063 - learning_rate: 1.0000e-04
# Epoch 138/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0986 - learning_rate: 1.0000e-04
# Epoch 139/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0956 - learning_rate: 1.0000e-04
# Epoch 140/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0918 - learning_rate: 1.0000e-04
# Epoch 141/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1047 - learning_rate: 1.0000e-04
# Epoch 142/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1182 - learning_rate: 1.0000e-04
# Epoch 143/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1053 - learning_rate: 1.0000e-04
# Epoch 144/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0808 - learning_rate: 1.0000e-04
# Epoch 145/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0959 - learning_rate: 1.0000e-04
# Epoch 146/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0922 - learning_rate: 1.0000e-04
# Epoch 147/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0923 - learning_rate: 1.0000e-04
# Epoch 148/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1147 - learning_rate: 1.0000e-04
# Epoch 149/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1084 - learning_rate: 1.0000e-04
# Epoch 150/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1112 - learning_rate: 1.0000e-04
# Epoch 151/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0900 - learning_rate: 1.0000e-04
# Epoch 152/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1151 - learning_rate: 1.0000e-04
# Epoch 153/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1023 - learning_rate: 1.0000e-04
# Epoch 154/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0702 - learning_rate: 1.0000e-04
# Epoch 155/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0777 - learning_rate: 1.0000e-04
# Epoch 156/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0971 - learning_rate: 1.0000e-04
# Epoch 157/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1042 - learning_rate: 1.0000e-04
# Epoch 158/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0918 - learning_rate: 1.0000e-04
# Epoch 159/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0985 - learning_rate: 1.0000e-04
# Epoch 160/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0960 - learning_rate: 1.0000e-04
# Epoch 161/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1012 - learning_rate: 1.0000e-04
# Epoch 162/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1051 - learning_rate: 1.0000e-04
# Epoch 163/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0995 - learning_rate: 1.0000e-04
# Epoch 164/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0742 - learning_rate: 1.0000e-04
# Epoch 165/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0922 - learning_rate: 1.0000e-04
# Epoch 166/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1079 - learning_rate: 1.0000e-04
# Epoch 167/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0965 - learning_rate: 1.0000e-04
# Epoch 168/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1025 - learning_rate: 1.0000e-04
# Epoch 169/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1008 - learning_rate: 1.0000e-04
# Epoch 170/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1042 - learning_rate: 1.0000e-04
# Epoch 171/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0936 - learning_rate: 1.0000e-04
# Epoch 172/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0898 - learning_rate: 1.0000e-04
# Epoch 173/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0899 - learning_rate: 1.0000e-04
# Epoch 174/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.1330 - learning_rate: 1.0000e-04
# Epoch 175/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0865 - learning_rate: 1.0000e-04
# Epoch 176/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1007 - learning_rate: 1.0000e-04
# Epoch 177/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1093 - learning_rate: 1.0000e-04
# Epoch 178/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0988 - learning_rate: 1.0000e-04
# Epoch 179/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1038 - learning_rate: 1.0000e-04
# Epoch 180/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0784 - learning_rate: 1.0000e-04
# Epoch 181/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0966 - learning_rate: 1.0000e-04
# Epoch 182/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1065 - learning_rate: 1.0000e-04
# Epoch 183/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1010 - learning_rate: 1.0000e-04
# Epoch 184/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1109 - learning_rate: 1.0000e-04
# Epoch 185/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1211 - learning_rate: 1.0000e-04
# Epoch 186/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0739 - learning_rate: 1.0000e-04
# Epoch 187/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1030 - learning_rate: 1.0000e-04
# Epoch 188/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0703 - learning_rate: 1.0000e-04
# Epoch 189/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0892 - learning_rate: 1.0000e-04
# Epoch 190/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1019 - learning_rate: 1.0000e-04
# Epoch 191/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0983 - learning_rate: 1.0000e-04
# Epoch 192/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0836 - learning_rate: 1.0000e-04
# Epoch 193/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1344 - learning_rate: 1.0000e-04
# Epoch 194/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1011 - learning_rate: 1.0000e-04
# Epoch 195/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0974 - learning_rate: 1.0000e-04
# Epoch 196/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0836 - learning_rate: 1.0000e-04
# Epoch 197/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0863 - learning_rate: 1.0000e-04
# Epoch 198/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1045 - learning_rate: 1.0000e-04
# Epoch 199/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0997 - learning_rate: 1.0000e-04
# Epoch 200/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1042 - learning_rate: 1.0000e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
